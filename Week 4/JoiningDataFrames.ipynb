# %%
# Joining DataFrames -- 27/05/24

# %%
# Load the dataset into df

# %%
import pandas as pd

# %%
df_a = pd.read_csv("SN7577i_a.csv")

# %%
df_a
# Out:
#    Id  Q1  Q2  Q3  Q4
# 0   1   1  -1   1   8
# 1   2   3  -1   1   4
# 2   3  10   3   2   6
# 3   4   9  -1  10  10
# 4   5  10   2   6   1
# 5   6   1  -1   1   1
# 6   7   1  -1   1   8
# 7   8   1  -1   1   1
# 8   9   9  -1  10  10
# 9  10   2  -1   1   1

# %%
df_b = pd.read_csv("SN7577i_b.csv")

# %%
df_b
# Out:
#      Id  Q1  Q2  Q3  Q4
# 0  1277  10  10   4   6
# 1  1278   2  -1   5   4
# 2  1279   2  -1   4   5
# 3  1280   1  -1   2   3
# 4  1281  10   2   3   4
# 5  1282   2  -1   3   6
# 6  1283  10  10   2  10
# 7  1284   9  -1   8   9
# 8  1285  11  11   1   2
# 9  1286  10   6   6   6

# %%
# Using concat to add the rows
df_a_b = pd.concat([df_a, df_b])

# %%
df_a_b
# Out:
#      Id  Q1  Q2  Q3  Q4
# 0     1   1  -1   1   8
# 1     2   3  -1   1   4
# 2     3  10   3   2   6
# 3     4   9  -1  10  10
# 4     5  10   2   6   1
# 5     6   1  -1   1   1
# 6     7   1  -1   1   8
# 7     8   1  -1   1   1
# 8     9   9  -1  10  10
# 9    10   2  -1   1   1
# 0  1277  10  10   4   6
# 1  1278   2  -1   5   4
# 2  1279   2  -1   4   5
# 3  1280   1  -1   2   3
# 4  1281  10   2   3   4
# 5  1282   2  -1   3   6
# 6  1283  10  10   2  10
# 7  1284   9  -1   8   9
# 8  1285  11  11   1   2
# 9  1286  10   6   6   6

# %%
# Concatenating dataframes with less columns

# %%
df_aa = pd.read_csv("SN7577i_aa.csv")

# %%
df_bb = pd.read_csv("SN7577i_bb.csv")

# %%
df_aa_bb = pd.concat([df_aa, df_bb])

# %%
df_aa_bb
# Out:
#      Id  Q1  Q2    Q3    Q4
# 0     1   1  -1   1.0   NaN
# 1     2   3  -1   1.0   NaN
# 2     3  10   3   2.0   NaN
# 3     4   9  -1  10.0   NaN
# 4     5  10   2   6.0   NaN
# 5     6   1  -1   1.0   NaN
# 6     7   1  -1   1.0   NaN
# 7     8   1  -1   1.0   NaN
# 8     9   9  -1  10.0   NaN
# 9    10   2  -1   1.0   NaN
# 0  1277  10  10   NaN   6.0
# 1  1278   2  -1   NaN   4.0
# 2  1279   2  -1   NaN   5.0
# 3  1280   1  -1   NaN   3.0
# 4  1281  10   2   NaN   4.0
# 5  1282   2  -1   NaN   6.0
# 6  1283  10  10   NaN  10.0
# 7  1284   9  -1   NaN   9.0
# 8  1285  11  11   NaN   2.0
# 9  1286  10   6   NaN   6.0

# %%
# Merge methods using 'how'
# Syntax: df_cd = pd.merge(df_SN7577i_c, df_SN7577i_d, how='inner', on = 'Id')

'''
Merge Methods:
1. Left (keys from left frame only) - 
2. Right (keys from right frame only) - 
3. Outer (keys from both, a union) - 
4. Inner (keys from the intersection of both, exists in a and b only) - 
'''
# Out:
# '\nMerge Methods:\n1. Left (keys from left frame only) - \n2. Right (keys from right frame only) - \n3. Outer (keys from both, a union) - \n4. Inner (keys from the intersection of both, exists in a and b only) - \n'

# %%
df_c = pd.read_csv("SN7577i_c.csv")

# %%
df_c.head()
# Out:
#    Id  maritl  numhhd
# 0   1       6       3
# 1   2       4       3
# 2   3       6       2
# 3   4       4       1
# 4   5       4       1

# %%
df_d = pd.read_csv("SN7577i_d.csv")

# %%
df_d.head()
# Out:
#    Id  Q1  Q2
# 0   1   1  -1
# 1   2   3  -1
# 2   3  10   3
# 3   4   9  -1
# 4   5  10   2

# %%
df_cd = pd.merge(df_c, df_d, how='inner', on = 'Id')

# %%
df_cd
# Out:
#    Id  maritl  numhhd  Q1  Q2
# 0   1       6       3   1  -1
# 1   2       4       3   3  -1
# 2   3       6       2  10   3
# 3   4       4       1   9  -1
# 4   5       4       1  10   2
# 5   6       2       2   1  -1
# 6   7       2       2   1  -1
# 7   8       2       2   1  -1
# 8   9       6       2   9  -1
# 9  10       6       1   2  -1

# %%
# Practice - by Dr. Kavu

# %%
df_auto = pd.read_csv("Automobile_data.csv")

# %%
# Print the first 5 rows
df_auto.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
# Print the last 5 rows
df_auto.tail()
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
# replace '?' columns with NaN
df_auto.replace(['?', 'n.a'], np.nan, inplace=True)

# %%
# print most expensive car with details of company name and price
# using idx.max()

dolla_bill_yall = df_auto.loc[df_auto['price'].idxmax()]

dolla_bill_comp_price = {
    'company': dolla_bill_yall['company'],
    'price': dolla_bill_yall['price']
}

print(dolla_bill_comp_price)
# Out:
# {'company': 'mercedes-benz', 'price': 45400.0}

# %%
# count total cars per company
cars_per_company = df_auto['company'].value_counts().reset_index()
print(cars_per_company)
# Out:
#             index  company
# 0          toyota        7
# 1             bmw        6
# 2           mazda        5
# 3          nissan        5
# 4            audi        4
# 5   mercedes-benz        4
# 6      mitsubishi        4
# 7      volkswagen        4
# 8     alfa-romero        3
# 9       chevrolet        3
# 10          honda        3
# 11          isuzu        3
# 12         jaguar        3
# 13        porsche        3
# 14          dodge        2
# 15          volvo        2

# %%
# average mileage of each car company
# Calculating the average mileage of each car company
average_mileage_per_company = df_auto.groupby('company')['average-mileage'].mean().reset_index()

print(average_mileage_per_company)
# Out:
#           company  average-mileage
# 0     alfa-romero        20.333333
# 1            audi        20.000000
# 2             bmw        19.000000
# 3       chevrolet        41.000000
# 4           dodge        31.000000
# 5           honda        26.333333
# 6           isuzu        33.333333
# 7          jaguar        14.333333
# 8           mazda        28.000000
# 9   mercedes-benz        18.000000
# 10     mitsubishi        29.500000
# 11         nissan        31.400000
# 12        porsche        17.000000
# 13         toyota        28.714286
# 14     volkswagen        31.750000
# 15          volvo        23.000000

# %%
# Sort all cars by Price column
sorted_cars = df_auto.sort_values(by='price')
sorted_cars
# Out:
#     index        company body-style  wheel-base  length engine-type  \
# 13     16      chevrolet  hatchback        88.4   141.1           l
# 27     36          mazda  hatchback        93.1   159.1         ohc
# 48     66         toyota  hatchback        95.7   158.7         ohc
# 36     49     mitsubishi  hatchback        93.7   157.3         ohc
# 28     37          mazda  hatchback        93.1   159.1         ohc
# ..    ...            ...        ...         ...     ...         ...
# 11     14            bmw      sedan       103.5   193.8         ohc
# 35     47  mercedes-benz    hardtop       112.0   199.2        ohcv
# 22     31          isuzu      sedan        94.5   155.9         ohc
# 23     32          isuzu      sedan        94.5   155.9         ohc
# 47     63        porsche  hatchback        98.4   175.7       dohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 13            three          48               47   5151.0
# ...
