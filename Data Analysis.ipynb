# %%
'''
AI\ ASSIGNMENT.ipynb
AI Assignment 1: Data Prep & Data Analysis
Nana Kwaku Amoako
Tue 28 May, 2024
'''

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
# Get URL of wikipedia page with data
url = "https://en.wikipedia.org/wiki/List_of_presidents_of_the_United_States"
page = requests.get(url)

# %%
# test that page is loaded successfully
page.status_code

# %%
# # parse page
soup = BeautifulSoup(page.content, 'html.parser')

# %%
# find the table in the webpage
table = soup.find('table', {'class': 'wikitable'})

# %%
# read table data into pandas DataFrame
df = pd.read_html(str(table))[0]

# %% [markdown]
# ### Question 1

# %%
# view that page read into df
df.head(46)

# %% [markdown]
# ### DATA CLEANING

# %%
# make a new birthyear column
# Initialize the Birth Year column with None
df['Birth Year'] = None

# Extract the birth year based on the format
for index, row in df.iterrows():
    name_birth_death = row['Name (Birth–Death)']
    if 'b. ' in name_birth_death:
        birth_year = name_birth_death.split('b. ')[1].split(')')[0].strip()
    else:
        birth_year = name_birth_death.split('(')[1].split('–')[0].strip()
    
    df.at[index, 'Birth Year'] = birth_year


# for birth in df['Name (Birth–Death)']:
#     if 'b. ' in birth:
#         birthyear = birth.split('b. ')[1].split('–')[0]
#         df['Birth Year'] = birthyear
#     else:
#         df['Birth Year'] = df['Name (Birth–Death)'].str.extract(r'\((?:b\.\s)?(\d{4})[–-]')

# %%
# make a death year column
df['Death Year'] = df['Name (Birth–Death)'].str.extract(r'[–-](\d{4})\)')
df['Death Year'].fillna('Alive', inplace=True)

# %%
# make the name column just names
df['Name'] = df['Name (Birth–Death)'].str.replace(r'\s*\(.*\)\s*', '', regex=True)

# %%
# drop the old name column 
df.drop(columns=['Name (Birth–Death)'], inplace=True)

# %%
# Drop the 'Portrait' column
df.columns = df.columns.str.strip() # clean trailing whitespaces
df.drop(columns=['Portrait'], axis=0, inplace=True)

# %%
# drop party[b][15] column
df.columns = df.columns.str.strip() # clean trailing whitespaces
df.drop(columns=['Party[b][15]'], axis=0, inplace=True)

# %%
# drop No.[a] column
df.drop(columns=['No.[a]'], axis=0, inplace=True)

# %%
df['Name'] = df['Name'].str.split('[').str[0].str.strip()

# %%
df['Vice President'] = df['Vice President[16]'].str.split('[').str[0].str.strip()
# drop old column
df = df.drop('Vice President[16]', axis=1)

# %%
df['Party'] = df['Party[b][15].1'].str.split('[').str[0].str.strip()
# drop old column
df = df.drop('Party[b][15].1', axis=1)

# %%
df['Term'] = df['Term[14]'].str.split('[').str[0].str.strip()
# drop old column
df = df.drop('Term[14]', axis=1)

# %%
# fill na's in election column
df.replace('–', np.nan, inplace=True)
df['Election'].fillna('No Election', inplace=True)

# %% [markdown]
# adding year entered and left office

# %%
from datetime import datetime

# Define date format
date = "%B %d, %Y"

# Initialize lists to hold the new column data
years_entered_office = []
years_left_office = []

# Loop through terms to extract start and end years
for term in df['Term']:
    try:
        # Split term into start and end date
        start_date, end_date = term.split(" – ")
        start = datetime.strptime(start_date.strip(), date)
        years_entered_office.append(start.year)

        # Incumbent workaround
        if end_date.strip() == 'Incumbent':
            end = datetime.now()
        else:
            end = datetime.strptime(end_date.strip(), date)
        years_left_office.append(end.year)
    except ValueError:
        # Handle terms with only one date (assuming it's the start date)
        start = datetime.strptime(term.strip(), date)
        years_entered_office.append(start.year)
        years_left_office.append(None)

# Add new columns to the dataframe
df['year entered office'] = years_entered_office
df['year left office'] = years_left_office


df
# Out:
#                Election Birth Year Death Year                    Name  \
# 0        1788–1789 1792       1732       1799       George Washington
# 1                  1796       1735       1826              John Adams
# 2             1800 1804       1743       1826        Thomas Jefferson
# 3             1808 1812       1751       1836           James Madison
# 4             1816 1820       1758       1831            James Monroe
# 5                  1824       1767       1848       John Quincy Adams
# 6             1828 1832       1767       1845          Andrew Jackson
# 7                  1836       1782       1862        Martin Van Buren
# 8                  1840       1773       1841  William Henry Harrison
# 9           No Election       1790       1862              John Tyler
# 10                 1844       1795       1849           James K. Polk
# 11                 1848       1784       1850          Zachary Taylor
# 12          No Election       1800       1874        Millard Fillmore
# 13                 1852       1804       1869         Franklin Pierce
# 14                 1856       1791       1868          James Buchanan
# 15            1860 1864       1809       1865         Abraham Lincoln
# 16          No Election       1808       1875          Andrew Johnson
# 17            1868 1872       1822       1885        Ulysses S. Grant
# 18                 1876       1822       1893     Rutherford B. Hayes
# 19                 1880       1831       1881       James A. Garfield
# 20          No Election       1829       1886       Chester A. Arthur
# 21                 1884       1837       1908        Grover Cleveland
# 22                 1888       1833       1901       Benjamin Harrison
# 23                 1892       1837       1908        Grover Cleveland
# 24            1896 1900       1843       1901        William McKinley
# 25               – 1904       1858       1919      Theodore Roosevelt
# 26                 1908       1857       1930     William Howard Taft
# 27            1912 1916       1856       1924          Woodrow Wilson
# 28                 1920       1865       1923       Warren G. Harding
# 29               – 1924       1872       1933         Calvin Coolidge
# 30                 1928       1874       1964          Herbert Hoover
# 31  1932 1936 1940 1944       1882       1945   Franklin D. Roosevelt
# 32               – 1948       1884       1972         Harry S. Truman
# 33            1952 1956       1890       1969    Dwight D. Eisenhower
# 34                 1960       1917       1963         John F. Kennedy
# 35               – 1964       1908       1973       Lyndon B. Johnson
# 36            1968 1972       1913       1994           Richard Nixon
# 37          No Election       1913       2006             Gerald Ford
# 38                 1976       1924          0            Jimmy Carter
# 39            1980 1984       1911       2004           Ronald Reagan
# 40                 1988       1924       2018       George H. W. Bush
# 41            1992 1996       1946          0            Bill Clinton
# 42            2000 2004       1946          0          George W. Bush
# 43            2008 2012       1961          0            Barack Obama
# 44                 2016       1946          0            Donald Trump
# 45                 2020       1942          0               Joe Biden
#
#                                        Vice President  \
# 0                                          John Adams
# 1                                    Thomas Jefferson
# 2                           Aaron Burr George Clinton
# 3                                      George Clinton
# 4                                  Daniel D. Tompkins
# 5                                     John C. Calhoun
# 6                                     John C. Calhoun
# 7                              Richard Mentor Johnson
# 8                                          John Tyler
# 9                        Vacant throughout presidency
# 10                                   George M. Dallas
# 11                                   Millard Fillmore
# 12                       Vacant throughout presidency
# 13                                    William R. King
# 14                               John C. Breckinridge
# 15                     Hannibal Hamlin Andrew Johnson
# 16                       Vacant throughout presidency
# 17                       Schuyler Colfax Henry Wilson
# 18                                 William A. Wheeler
# 19                                  Chester A. Arthur
# 20                       Vacant throughout presidency
# 21                                Thomas A. Hendricks
# 22                                     Levi P. Morton
# 23                                  Adlai Stevenson I
# 24                                      Garret Hobart
# 25  Vacant through March 4, 1905 Charles W. Fairbanks
# 26                                   James S. Sherman
# 27                                 Thomas R. Marshall
# 28                                    Calvin Coolidge
# 29      Vacant through March 4, 1925 Charles G. Dawes
# 30                                     Charles Curtis
# 31  John Nance Garner Henry A. Wallace Harry S. Tr...
# 32   Vacant through January 20, 1949 Alben W. Barkley
# 33                                      Richard Nixon
# 34                                  Lyndon B. Johnson
# 35    Vacant through January 20, 1965 Hubert Humphrey
# 36                                        Spiro Agnew
# 37  Vacant through December 19, 1974 Nelson Rockef...
# 38                                     Walter Mondale
# 39                                  George H. W. Bush
# 40                                         Dan Quayle
# 41                                            Al Gore
# 42                                        Dick Cheney
# 43                                          Joe Biden
# 44                                         Mike Pence
# 45                                      Kamala Harris
#
#                         Party                                  Term  \
# 0                Unaffiliated        April 30, 1789 – March 4, 1797
# 1                  Federalist         March 4, 1797 – March 4, 1801
# 2      Democratic- Republican         March 4, 1801 – March 4, 1809
# 3      Democratic- Republican         March 4, 1809 – March 4, 1817
# 4      Democratic- Republican         March 4, 1817 – March 4, 1825
# 5      Democratic- Republican         March 4, 1825 – March 4, 1829
# 6                  Democratic         March 4, 1829 – March 4, 1837
# 7                  Democratic         March 4, 1837 – March 4, 1841
# 8                        Whig         March 4, 1841 – April 4, 1841
# 9                        Whig                         April 4, 1841
# 10                 Democratic         March 4, 1845 – March 4, 1849
# 11                       Whig          March 4, 1849 – July 9, 1850
# 12                       Whig                          July 9, 1850
# 13                 Democratic         March 4, 1853 – March 4, 1857
# 14                 Democratic         March 4, 1857 – March 4, 1861
# 15  Republican National Union        March 4, 1861 – April 15, 1865
# 16             National Union                        April 15, 1865
# 17                 Republican         March 4, 1869 – March 4, 1877
# 18                 Republican         March 4, 1877 – March 4, 1881
# 19                 Republican    March 4, 1881 – September 19, 1881
# 20                 Republican                    September 19, 1881
# 21                 Democratic         March 4, 1885 – March 4, 1889
# 22                 Republican         March 4, 1889 – March 4, 1893
# 23                 Democratic         March 4, 1893 – March 4, 1897
# 24                 Republican    March 4, 1897 – September 14, 1901
# 25                 Republican                    September 14, 1901
# 26                 Republican         March 4, 1909 – March 4, 1913
# 27                 Democratic         March 4, 1913 – March 4, 1921
# 28                 Republican        March 4, 1921 – August 2, 1923
# 29                 Republican                        August 2, 1923
# 30                 Republican         March 4, 1929 – March 4, 1933
# 31                 Democratic        March 4, 1933 – April 12, 1945
# 32                 Democratic                        April 12, 1945
# 33                 Republican   January 20, 1953 – January 20, 1961
# 34                 Democratic  January 20, 1961 – November 22, 1963
# 35                 Democratic                     November 22, 1963
# 36                 Republican     January 20, 1969 – August 9, 1974
# 37                 Republican                        August 9, 1974
# 38                 Democratic   January 20, 1977 – January 20, 1981
# 39                 Republican   January 20, 1981 – January 20, 1989
# 40                 Republican   January 20, 1989 – January 20, 1993
# 41                 Democratic   January 20, 1993 – January 20, 2001
# 42                 Republican   January 20, 2001 – January 20, 2009
# 43                 Democratic   January 20, 2009 – January 20, 2017
# 44                 Republican   January 20, 2017 – January 20, 2021
# 45                 Democratic          January 20, 2021 – Incumbent
#
#     year entered office  year left office  Years in Office    Forename  \
# 0                  1789            1797.0                8      George
# 1                  1797            1801.0                4        John
# 2                  1801            1809.0                8      Thomas
# 3                  1809            1817.0                8       James
# 4                  1817            1825.0                8       James
# 5                  1825            1829.0                4        John
# 6                  1829            1837.0                8      Andrew
# 7                  1837            1841.0                4      Martin
# 8                  1841            1841.0                0     William
# 9                  1841               NaN                4        John
# 10                 1845            1849.0                4       James
# 11                 1849            1850.0                1     Zachary
# 12                 1850               NaN                3     Millard
# 13                 1853            1857.0                4    Franklin
# 14                 1857            1861.0                4       James
# 15                 1861            1865.0                4     Abraham
# 16                 1865               NaN                4      Andrew
# 17                 1869            1877.0                8     Ulysses
# 18                 1877            1881.0                4  Rutherford
# 19                 1881            1881.0                0       James
# 20                 1881               NaN                4     Chester
# 21                 1885            1889.0                4      Grover
# 22                 1889            1893.0                4    Benjamin
# 23                 1893            1897.0                4      Grover
# 24                 1897            1901.0                4     William
# 25                 1901               NaN                8    Theodore
# 26                 1909            1913.0                4     William
# 27                 1913            1921.0                8     Woodrow
# 28                 1921            1923.0                2      Warren
# 29                 1923               NaN                6      Calvin
# 30                 1929            1933.0                4     Herbert
# 31                 1933            1945.0               12    Franklin
# 32                 1945               NaN                8       Harry
# 33                 1953            1961.0                8      Dwight
# 34                 1961            1963.0                2        John
# 35                 1963               NaN                6      Lyndon
# 36                 1969            1974.0                5     Richard
# 37                 1974               NaN                3      Gerald
# 38                 1977            1981.0                4       Jimmy
# 39                 1981            1989.0                8      Ronald
# 40                 1989            1993.0                4      George
# 41                 1993            2001.0                8        Bill
# 42                 2001            2009.0                8      George
# 43                 2009            2017.0                8      Barack
# 44                 2017            2021.0                4      Donald
# 45                 2021            2024.0                3         Joe
#
#        Surname      VP                                  VP more than once
# 0   Washington                                                 John Adams
# 1        Adams   Short
# 2    Jefferson                                  Aaron Burr George Clinton
# 3      Madison                                             George Clinton
# 4       Monroe                                         Daniel D. Tompkins
# 5        Adams   Short
# 6      Jackson                                            John C. Calhoun
# 7        Buren   Short
# 8     Harrison   Short
# 9        Tyler   Short
# 10        Polk   Short
# 11      Taylor   Short
# 12    Fillmore   Short
# 13      Pierce   Short
# 14    Buchanan   Short
# 15     Lincoln   Short
# 16     Johnson   Short
# 17       Grant                               Schuyler Colfax Henry Wilson
# 18       Hayes   Short
# 19    Garfield   Short
# 20      Arthur   Short
# 21   Cleveland   Short
# 22    Harrison   Short
# 23   Cleveland   Short
# 24    McKinley   Short
# 25   Roosevelt  Vacant
# 26        Taft   Short
# 27      Wilson                                         Thomas R. Marshall
# 28     Harding   Short
# 29    Coolidge  Vacant
# 30      Hoover   Short
# 31   Roosevelt          John Nance Garner Henry A. Wallace Harry S. Tr...
# 32      Truman  Vacant
# 33  Eisenhower                                              Richard Nixon
# 34     Kennedy   Short
# 35     Johnson  Vacant
# 36       Nixon                                                Spiro Agnew
# 37        Ford   Short
# 38      Carter   Short
# 39      Reagan                                          George H. W. Bush
# 40        Bush   Short
# 41     Clinton                                                    Al Gore
# 42        Bush                                                Dick Cheney
# 43       Obama                                                  Joe Biden
# 44       Trump   Short
# 45       Biden   Short

# %% [markdown]
# ### Question 2: How many presidents are on the web page ?

# %%
# 2: Presidents on webpage
presidents_num = df['Name'].nunique()
print(f"The number of presidents on the webpage is: {presidents_num}")

# %% [markdown]
# ### Question 3: How many presidencies ever existed in the United states ?

# %%
# 3: Presidencies existing in the US
presidencies_num = len(df)
print(f"The number of presidencies in the US is: {presidencies_num}")

# %% [markdown]
# ### Question 4: Which presidents served more than one term and had only one vice president for the whole duration of their presidency?

# %% [markdown]
# Cleaning vp column further

# %%
# 4: More than one term
from datetime import datetime

# date format
date = "%B %d, %Y"

years_in_office = []

# loop through terms to calculate how long mandem been in office
for i in range(len(df['Term'])):
    # get start and end date
    try:
        term = df['Term'][i] # Term will be the index we are traversing at 
        start_date, end_date = term.split(" – ")
        start = datetime.strptime(start_date.strip(), date) # convert to datetime object

        # Incumbent workaround
        if end_date.strip() == 'Incumbent':
            end = datetime.now()
        else:
            end = datetime.strptime(end_date.strip(), date)


        # Calculating years in office
        office_years = (end.year - start.year)
        years_in_office.append(office_years) # adding the years in office to the list
    except ValueError:
        # terms with no end date
        start = datetime.strptime(term.strip(), date)   # take the start date from the row as it is 

        # Logic: use start date of next term
        # i, i+1

        if i+1 < len(df['Term']):
            next_term = df['Term'][i+1]
            next_start_date, _ = next_term.split(" – ")
            end = datetime.strptime(next_start_date.strip(), date)
        else:
            end = datetime.now() 
        
        office_years = (end.year - start.year)
        years_in_office.append(office_years) # adding the years in office to the list

# %%
# Add years_in_office df
df['Years in Office'] = years_in_office

# %%
vp_list = []

for vp in df['Vice President']:
    if 'Vacant' in vp:
        if 'through' in vp:
            # handle partial vacancies
            parts = vp.split('through')
            date = parts[1].split()[:3] 
            remaining_vp = ' '.join(parts[1].split()[3:]) 
            vp_list.append(f"Vacant through {' '.join(date)} - {remaining_vp}")
        else:
            # handle complete vacancies
            vp_list.append('Vacant throughout presidency')
    else:
        # split names 
        vp_names = vp.split()
        if len(vp_names) > 3:
            vp_list.append(' - '.join([' '.join(vp_names[:3]), ' '.join(vp_names[3:])]))
        elif len(vp_names) == 4:
            vp_list.append(' - '.join([' '.join(vp_names[:2]), ' '.join(vp_names[2:])]))
        else:
            vp_list.append(' '.join(vp_names))


df['VP'] = vp_list

# %%
# new column with the vice presidents who served more than once

df['VP'] = ''
df['VP more than once'] = ''

for i in range(len(df)):
    if df['Years in Office'][i] > 4:
        if 'Vacant' in df['Vice President'][i]:
            df['VP'][i] = 'Vacant'
        else:
            df['VP more than once'][i] = df['Vice President'][i]
    else:
        df['VP'][i] = 'Short' # vice president didn't serve for long
# Out:
# /var/folders/wt/b9wfm1hx0s9gb4gpzpv0xyq40000gn/T/ipykernel_23320/513237849.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VP more than once'][i] = df['Vice President'][i]
# /var/folders/wt/b9wfm1hx0s9gb4gpzpv0xyq40000gn/T/ipykernel_23320/513237849.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VP'][i] = 'Short' # vice president didn't serve for long
# /var/folders/wt/b9wfm1hx0s9gb4gpzpv0xyq40000gn/T/ipykernel_23320/513237849.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VP'][i] = 'Vacant'

# %%
# print stuff

print("Presidents who only served for more than one term: ")
for i in range(len(df)):
    if df['Years in Office'][i] > 4:
        print(df['Name'][i])
# Out:
# Presidents who only served for more than one term:
# George Washington
# Thomas Jefferson
# James Madison
# James Monroe
# Andrew Jackson
# Ulysses S. Grant
# Theodore Roosevelt
# Woodrow Wilson
# Calvin Coolidge
# Franklin D. Roosevelt
# Harry S. Truman
# Dwight D. Eisenhower
# Lyndon B. Johnson
# Richard Nixon
# Ronald Reagan
# Bill Clinton
# George W. Bush
# Barack Obama

# %%
print("Presidents who only had one VP: ")
for i in range(len(df)):
    if len(df['VP more than once'][i]) > 2:
        print(df['Name'][i])
# Out:
# Presidents who only had one VP:
# George Washington
# Thomas Jefferson
# James Madison
# James Monroe
# Andrew Jackson
# Ulysses S. Grant
# Woodrow Wilson
# Franklin D. Roosevelt
# Dwight D. Eisenhower
# Richard Nixon
# Ronald Reagan
# Bill Clinton
# George W. Bush
# Barack Obama

# %% [markdown]
# ### Question 5: Which president was in office longer than others and when did he get in office?

# %%
max_year = df['Years in Office'].max()
pres_max_year = df[df['Years in Office'] == max_year]['Name'].to_string(index=False)
election_year =  df[df['Years in Office'] == max_year]['Election'].values[0]
election_year_value = election_year.split(' ')[0]

# print(max_year)
# print(pres_max_year)
# print(election_year_value)

print(f"The president who was in the office longest was {pres_max_year} with {max_year} years in office. He got into office in {election_year_value}")
# Out:
# The president who was in the office longest was Franklin D. Roosevelt with 12 years in office. He got into office in 1932

# %% [markdown]
# ### Question 6: Which presidents were elected after serving as vice presidents?

# %%
# loop through vp list
# if vp name exists in pres list
# print it

# Goal: The code managed to pick the names of the presidents who once served as vice presidents and the periods they served as vice president and president
vp_pres = []

for vp in df['Vice President']:
    for name in df['Name']:
        if name in vp:
            vp_pres.append(vp)


print("The presidents who were elected after serving as vice presidents are:", ', '.join(vp_pres))
print(f"and they are {len(vp_pres)} in number.")
# Out:
# The presidents who were elected after serving as vice presidents are: John Adams, Thomas Jefferson, John Tyler, Millard Fillmore, Hannibal Hamlin Andrew Johnson, Chester A. Arthur, Calvin Coolidge, John Nance Garner Henry A. Wallace Harry S. Truman, Richard Nixon, Lyndon B. Johnson, George H. W. Bush, Joe Biden
# and they are 12 in number.

# %% [markdown]
# ### Question 7: How many presidents were never elected, and what are their names?

# %%
# no election
# picks the president
# prints the presido

no_elect_guys = []

no_elect_guys = df[df['Election'] == 'No Election']['Name'].to_list()

print("The presidents who were never elected are:",', '.join(no_elect_guys))
print(f"and they are {len(no_elect_guys)}")
# Out:
# The presidents who were never elected are: John Tyler, Millard Fillmore, Andrew Johnson, Chester A. Arthur, Gerald Ford
# and they are 5

# %% [markdown]
# ### Question 8: How many presidents have the same forenames and/or surnames and who are they?

# %%
# cleaning
df['Forename'] = df['Name'].str.split().str[0]
df['Surname'] = df['Name'].str.split().str[-1]

# %%
# fisrt name
dupli_fname = df.duplicated(subset=["Forename"], keep=False)
dupli_fname_pres = df[dupli_fname]['Name'].tolist()
print("List of presidents with the same first name:")
print(f"{dupli_fname_pres}")
print(f"and they are {len(dupli_fname_pres)} in number")
# Out:
# List of presidents with the same first name:
# ['George Washington', 'John Adams', 'James Madison', 'James Monroe', 'John Quincy Adams', 'Andrew Jackson', 'William Henry Harrison', 'John Tyler', 'James K. Polk', 'Franklin Pierce', 'James Buchanan', 'Andrew Johnson', 'James A. Garfield', 'Grover Cleveland', 'Grover Cleveland', 'William McKinley', 'William Howard Taft', 'Franklin D. Roosevelt', 'John F. Kennedy', 'George H. W. Bush', 'George W. Bush']
# and they are 21 in number

# %%
# LAST NAME
dupli_lname = df.duplicated(subset=["Surname"], keep=False)
dupli_lname_pres = df[dupli_lname]['Name'].tolist()
print("List of presidents with the same last name:")
print(f"{dupli_lname_pres}")
print(f"and they are {len(dupli_lname_pres)} in number")
# Out:
# List of presidents with the same last name:
# ['John Adams', 'John Quincy Adams', 'William Henry Harrison', 'Andrew Johnson', 'Grover Cleveland', 'Benjamin Harrison', 'Grover Cleveland', 'Theodore Roosevelt', 'Franklin D. Roosevelt', 'Lyndon B. Johnson', 'George H. W. Bush', 'George W. Bush']
# and they are 12 in number

# %%
# displays the presidents with the same first name and their term
print("Presidents with the same first name and the term they served")
df[df['Name'].isin(dupli_fname_pres)][['Name', 'Term']]
# Out:
# Presidents with the same first name and the term they served
#                       Name                                  Term
# 0        George Washington        April 30, 1789 – March 4, 1797
# 1               John Adams         March 4, 1797 – March 4, 1801
# 3            James Madison         March 4, 1809 – March 4, 1817
# 4             James Monroe         March 4, 1817 – March 4, 1825
# 5        John Quincy Adams         March 4, 1825 – March 4, 1829
# 6           Andrew Jackson         March 4, 1829 – March 4, 1837
# 8   William Henry Harrison         March 4, 1841 – April 4, 1841
# 9               John Tyler                         April 4, 1841
# 10           James K. Polk         March 4, 1845 – March 4, 1849
# 13         Franklin Pierce         March 4, 1853 – March 4, 1857
# 14          James Buchanan         March 4, 1857 – March 4, 1861
# 16          Andrew Johnson                        April 15, 1865
# 19       James A. Garfield    March 4, 1881 – September 19, 1881
# 21        Grover Cleveland         March 4, 1885 – March 4, 1889
# 23        Grover Cleveland         March 4, 1893 – March 4, 1897
# 24        William McKinley    March 4, 1897 – September 14, 1901
# 26     William Howard Taft         March 4, 1909 – March 4, 1913
# 31   Franklin D. Roosevelt        March 4, 1933 – April 12, 1945
# 34         John F. Kennedy  January 20, 1961 – November 22, 1963
# 40       George H. W. Bush   January 20, 1989 – January 20, 1993
# 42          George W. Bush   January 20, 2001 – January 20, 2009

# %%
print("Presidents with the same first name and the term they served")
df[df['Name'].isin(dupli_lname_pres)][['Name', 'Term']]
# Out:
# Presidents with the same first name and the term they served
#                       Name                                 Term
# 1               John Adams        March 4, 1797 – March 4, 1801
# 5        John Quincy Adams        March 4, 1825 – March 4, 1829
# 8   William Henry Harrison        March 4, 1841 – April 4, 1841
# 16          Andrew Johnson                       April 15, 1865
# 21        Grover Cleveland        March 4, 1885 – March 4, 1889
# 22       Benjamin Harrison        March 4, 1889 – March 4, 1893
# 23        Grover Cleveland        March 4, 1893 – March 4, 1897
# 25      Theodore Roosevelt                   September 14, 1901
# 31   Franklin D. Roosevelt       March 4, 1933 – April 12, 1945
# 35       Lyndon B. Johnson                    November 22, 1963
# 40       George H. W. Bush  January 20, 1989 – January 20, 1993
# 42          George W. Bush  January 20, 2001 – January 20, 2009

# %%
df
# Out:
#                Election Birth Year Death Year                    Name  \
# 0        1788–1789 1792       1732       1799       George Washington
# 1                  1796       1735       1826              John Adams
# 2             1800 1804       1743       1826        Thomas Jefferson
# 3             1808 1812       1751       1836           James Madison
# 4             1816 1820       1758       1831            James Monroe
# 5                  1824       1767       1848       John Quincy Adams
# 6             1828 1832       1767       1845          Andrew Jackson
# 7                  1836       1782       1862        Martin Van Buren
# 8                  1840       1773       1841  William Henry Harrison
# 9           No Election       1790       1862              John Tyler
# 10                 1844       1795       1849           James K. Polk
# 11                 1848       1784       1850          Zachary Taylor
# 12          No Election       1800       1874        Millard Fillmore
# 13                 1852       1804       1869         Franklin Pierce
# 14                 1856       1791       1868          James Buchanan
# 15            1860 1864       1809       1865         Abraham Lincoln
# 16          No Election       1808       1875          Andrew Johnson
# 17            1868 1872       1822       1885        Ulysses S. Grant
# 18                 1876       1822       1893     Rutherford B. Hayes
# 19                 1880       1831       1881       James A. Garfield
# 20          No Election       1829       1886       Chester A. Arthur
# 21                 1884       1837       1908        Grover Cleveland
# 22                 1888       1833       1901       Benjamin Harrison
# 23                 1892       1837       1908        Grover Cleveland
# 24            1896 1900       1843       1901        William McKinley
# 25               – 1904       1858       1919      Theodore Roosevelt
# 26                 1908       1857       1930     William Howard Taft
# 27            1912 1916       1856       1924          Woodrow Wilson
# 28                 1920       1865       1923       Warren G. Harding
# 29               – 1924       1872       1933         Calvin Coolidge
# 30                 1928       1874       1964          Herbert Hoover
# 31  1932 1936 1940 1944       1882       1945   Franklin D. Roosevelt
# 32               – 1948       1884       1972         Harry S. Truman
# 33            1952 1956       1890       1969    Dwight D. Eisenhower
# 34                 1960       1917       1963         John F. Kennedy
# 35               – 1964       1908       1973       Lyndon B. Johnson
# 36            1968 1972       1913       1994           Richard Nixon
# 37          No Election       1913       2006             Gerald Ford
# 38                 1976       1924      Alive            Jimmy Carter
# 39            1980 1984       1911       2004           Ronald Reagan
# 40                 1988       1924       2018       George H. W. Bush
# 41            1992 1996       1946      Alive            Bill Clinton
# 42            2000 2004       1946      Alive          George W. Bush
# 43            2008 2012       1961      Alive            Barack Obama
# 44                 2016       1946      Alive            Donald Trump
# 45                 2020       1942      Alive               Joe Biden
#
#                                        Vice President  \
# 0                                          John Adams
# 1                                    Thomas Jefferson
# 2                           Aaron Burr George Clinton
# 3                                      George Clinton
# 4                                  Daniel D. Tompkins
# 5                                     John C. Calhoun
# 6                                     John C. Calhoun
# 7                              Richard Mentor Johnson
# 8                                          John Tyler
# 9                        Vacant throughout presidency
# 10                                   George M. Dallas
# 11                                   Millard Fillmore
# 12                       Vacant throughout presidency
# 13                                    William R. King
# 14                               John C. Breckinridge
# 15                     Hannibal Hamlin Andrew Johnson
# 16                       Vacant throughout presidency
# 17                       Schuyler Colfax Henry Wilson
# 18                                 William A. Wheeler
# 19                                  Chester A. Arthur
# 20                       Vacant throughout presidency
# 21                                Thomas A. Hendricks
# 22                                     Levi P. Morton
# 23                                  Adlai Stevenson I
# 24                                      Garret Hobart
# 25  Vacant through March 4, 1905 Charles W. Fairbanks
# 26                                   James S. Sherman
# 27                                 Thomas R. Marshall
# 28                                    Calvin Coolidge
# 29      Vacant through March 4, 1925 Charles G. Dawes
# 30                                     Charles Curtis
# 31  John Nance Garner Henry A. Wallace Harry S. Tr...
# 32   Vacant through January 20, 1949 Alben W. Barkley
# 33                                      Richard Nixon
# 34                                  Lyndon B. Johnson
# 35    Vacant through January 20, 1965 Hubert Humphrey
# 36                                        Spiro Agnew
# 37  Vacant through December 19, 1974 Nelson Rockef...
# 38                                     Walter Mondale
# 39                                  George H. W. Bush
# 40                                         Dan Quayle
# 41                                            Al Gore
# 42                                        Dick Cheney
# 43                                          Joe Biden
# 44                                         Mike Pence
# 45                                      Kamala Harris
#
#                         Party                                  Term  \
# 0                Unaffiliated        April 30, 1789 – March 4, 1797
# 1                  Federalist         March 4, 1797 – March 4, 1801
# 2      Democratic- Republican         March 4, 1801 – March 4, 1809
# 3      Democratic- Republican         March 4, 1809 – March 4, 1817
# 4      Democratic- Republican         March 4, 1817 – March 4, 1825
# 5      Democratic- Republican         March 4, 1825 – March 4, 1829
# 6                  Democratic         March 4, 1829 – March 4, 1837
# 7                  Democratic         March 4, 1837 – March 4, 1841
# 8                        Whig         March 4, 1841 – April 4, 1841
# 9                        Whig                         April 4, 1841
# 10                 Democratic         March 4, 1845 – March 4, 1849
# 11                       Whig          March 4, 1849 – July 9, 1850
# 12                       Whig                          July 9, 1850
# 13                 Democratic         March 4, 1853 – March 4, 1857
# 14                 Democratic         March 4, 1857 – March 4, 1861
# 15  Republican National Union        March 4, 1861 – April 15, 1865
# 16             National Union                        April 15, 1865
# 17                 Republican         March 4, 1869 – March 4, 1877
# 18                 Republican         March 4, 1877 – March 4, 1881
# 19                 Republican    March 4, 1881 – September 19, 1881
# 20                 Republican                    September 19, 1881
# 21                 Democratic         March 4, 1885 – March 4, 1889
# 22                 Republican         March 4, 1889 – March 4, 1893
# 23                 Democratic         March 4, 1893 – March 4, 1897
# 24                 Republican    March 4, 1897 – September 14, 1901
# 25                 Republican                    September 14, 1901
# 26                 Republican         March 4, 1909 – March 4, 1913
# 27                 Democratic         March 4, 1913 – March 4, 1921
# 28                 Republican        March 4, 1921 – August 2, 1923
# 29                 Republican                        August 2, 1923
# 30                 Republican         March 4, 1929 – March 4, 1933
# 31                 Democratic        March 4, 1933 – April 12, 1945
# 32                 Democratic                        April 12, 1945
# 33                 Republican   January 20, 1953 – January 20, 1961
# 34                 Democratic  January 20, 1961 – November 22, 1963
# 35                 Democratic                     November 22, 1963
# 36                 Republican     January 20, 1969 – August 9, 1974
# 37                 Republican                        August 9, 1974
# 38                 Democratic   January 20, 1977 – January 20, 1981
# 39                 Republican   January 20, 1981 – January 20, 1989
# 40                 Republican   January 20, 1989 – January 20, 1993
# 41                 Democratic   January 20, 1993 – January 20, 2001
# 42                 Republican   January 20, 2001 – January 20, 2009
# 43                 Democratic   January 20, 2009 – January 20, 2017
# 44                 Republican   January 20, 2017 – January 20, 2021
# 45                 Democratic          January 20, 2021 – Incumbent
#
#     year entered office  year left office  Years in Office    Forename  \
# 0                  1789            1797.0                8      George
# 1                  1797            1801.0                4        John
# 2                  1801            1809.0                8      Thomas
# 3                  1809            1817.0                8       James
# 4                  1817            1825.0                8       James
# 5                  1825            1829.0                4        John
# 6                  1829            1837.0                8      Andrew
# 7                  1837            1841.0                4      Martin
# 8                  1841            1841.0                0     William
# 9                  1841               NaN                4        John
# 10                 1845            1849.0                4       James
# 11                 1849            1850.0                1     Zachary
# 12                 1850               NaN                3     Millard
# 13                 1853            1857.0                4    Franklin
# 14                 1857            1861.0                4       James
# 15                 1861            1865.0                4     Abraham
# 16                 1865               NaN                4      Andrew
# 17                 1869            1877.0                8     Ulysses
# 18                 1877            1881.0                4  Rutherford
# 19                 1881            1881.0                0       James
# 20                 1881               NaN                4     Chester
# 21                 1885            1889.0                4      Grover
# 22                 1889            1893.0                4    Benjamin
# 23                 1893            1897.0                4      Grover
# 24                 1897            1901.0                4     William
# 25                 1901               NaN                8    Theodore
# 26                 1909            1913.0                4     William
# 27                 1913            1921.0                8     Woodrow
# 28                 1921            1923.0                2      Warren
# 29                 1923               NaN                6      Calvin
# 30                 1929            1933.0                4     Herbert
# 31                 1933            1945.0               12    Franklin
# 32                 1945               NaN                8       Harry
# 33                 1953            1961.0                8      Dwight
# 34                 1961            1963.0                2        John
# 35                 1963               NaN                6      Lyndon
# 36                 1969            1974.0                5     Richard
# 37                 1974               NaN                3      Gerald
# 38                 1977            1981.0                4       Jimmy
# 39                 1981            1989.0                8      Ronald
# 40                 1989            1993.0                4      George
# 41                 1993            2001.0                8        Bill
# 42                 2001            2009.0                8      George
# 43                 2009            2017.0                8      Barack
# 44                 2017            2021.0                4      Donald
# 45                 2021            2024.0                3         Joe
#
#        Surname      VP                                  VP more than once
# 0   Washington                                                 John Adams
# 1        Adams   Short
# 2    Jefferson                                  Aaron Burr George Clinton
# 3      Madison                                             George Clinton
# 4       Monroe                                         Daniel D. Tompkins
# 5        Adams   Short
# 6      Jackson                                            John C. Calhoun
# 7        Buren   Short
# 8     Harrison   Short
# 9        Tyler   Short
# 10        Polk   Short
# 11      Taylor   Short
# 12    Fillmore   Short
# 13      Pierce   Short
# 14    Buchanan   Short
# 15     Lincoln   Short
# 16     Johnson   Short
# 17       Grant                               Schuyler Colfax Henry Wilson
# 18       Hayes   Short
# 19    Garfield   Short
# 20      Arthur   Short
# 21   Cleveland   Short
# 22    Harrison   Short
# 23   Cleveland   Short
# 24    McKinley   Short
# 25   Roosevelt  Vacant
# 26        Taft   Short
# 27      Wilson                                         Thomas R. Marshall
# 28     Harding   Short
# 29    Coolidge  Vacant
# 30      Hoover   Short
# 31   Roosevelt          John Nance Garner Henry A. Wallace Harry S. Tr...
# 32      Truman  Vacant
# 33  Eisenhower                                              Richard Nixon
# 34     Kennedy   Short
# 35     Johnson  Vacant
# 36       Nixon                                                Spiro Agnew
# 37        Ford   Short
# 38      Carter   Short
# 39      Reagan                                          George H. W. Bush
# 40        Bush   Short
# 41     Clinton                                                    Al Gore
# 42        Bush                                                Dick Cheney
# 43       Obama                                                  Joe Biden
# 44       Trump   Short
# 45       Biden   Short

# %% [markdown]
# ### Question 9: Who was the oldest president ever elected for office?

# %%
oldest_pres = 0
oldest_president = ''
year_entered_office = 0
year_left_office = 0

# %%
for i in range(len(df)):
    election_years = df['Election'][i].split()
    for year in election_years:
        if year.isdigit():  # Check if the election year is a digit
            election_age = int(year) - int(df['Birth Year'][i])
            if election_age > oldest_pres:
                oldest_pres = election_age
                oldest_president = df['Name'][i]
                year_entered_office = df['year entered office'][i]
                year_left_office = df['year left office'][i]

# %%
print(f"The oldest president ever elected for office is {oldest_president} at {oldest_pres} years old.")
print(f"he assumed office in {year_entered_office} and left {int(year_left_office)}")
print(f"Duration of presidency: {int(year_left_office - year_entered_office)} years")
# Out:
# The oldest president ever elected for office is Joe Biden at 78 years old.
# he assumed office in 2021 and left 2024
# Duration of presidency: 3 years

# %% [markdown]
# ### Question 10: Who was the youngest president ever elected for office?

# %%
youngest_pres = float('inf')
youngest_president = ''
year_entered_office = 0
year_left_office = 0

# %%
for i in range(len(df)):
    election_years = df['Election'][i].split()
    for year in election_years:
        if year.isdigit():  # Check if the election year is a digit
            election_age = int(year) - int(df['Birth Year'][i])
            if election_age < youngest_pres:
                youngest_pres = election_age
                youngest_president = df['Name'][i]
                young_year_entered_office = df['year entered office'][i]
                young_year_left_office = df['year left office'][i]

# %%
print(f"The oldest president ever elected for office is {youngest_president} at {youngest_pres} years old.")
print(f"he assumed office in {young_year_entered_office} and left {int(young_year_left_office)}")
print(f"Duration of presidency: {int(young_year_left_office - young_year_entered_office)} years")
# Out:
# The oldest president ever elected for office is John F. Kennedy at 43 years old.
# he assumed office in 1961 and left 1963
# Duration of presidency: 2 years

# %% [markdown]
# ### Question 11: Which president lived up to a very old age, after leaving office?

# %%
oldest_age = 0
presname = ''
tenure_began = ''
tenure_end = ''

# %%
df
# Out:
#                Election Birth Year Death Year                    Name  \
# 0        1788–1789 1792       1732       1799       George Washington
# 1                  1796       1735       1826              John Adams
# 2             1800 1804       1743       1826        Thomas Jefferson
# 3             1808 1812       1751       1836           James Madison
# 4             1816 1820       1758       1831            James Monroe
# 5                  1824       1767       1848       John Quincy Adams
# 6             1828 1832       1767       1845          Andrew Jackson
# 7                  1836       1782       1862        Martin Van Buren
# 8                  1840       1773       1841  William Henry Harrison
# 9           No Election       1790       1862              John Tyler
# 10                 1844       1795       1849           James K. Polk
# 11                 1848       1784       1850          Zachary Taylor
# 12          No Election       1800       1874        Millard Fillmore
# 13                 1852       1804       1869         Franklin Pierce
# 14                 1856       1791       1868          James Buchanan
# 15            1860 1864       1809       1865         Abraham Lincoln
# 16          No Election       1808       1875          Andrew Johnson
# 17            1868 1872       1822       1885        Ulysses S. Grant
# 18                 1876       1822       1893     Rutherford B. Hayes
# 19                 1880       1831       1881       James A. Garfield
# 20          No Election       1829       1886       Chester A. Arthur
# 21                 1884       1837       1908        Grover Cleveland
# 22                 1888       1833       1901       Benjamin Harrison
# 23                 1892       1837       1908        Grover Cleveland
# 24            1896 1900       1843       1901        William McKinley
# 25               – 1904       1858       1919      Theodore Roosevelt
# 26                 1908       1857       1930     William Howard Taft
# 27            1912 1916       1856       1924          Woodrow Wilson
# 28                 1920       1865       1923       Warren G. Harding
# 29               – 1924       1872       1933         Calvin Coolidge
# 30                 1928       1874       1964          Herbert Hoover
# 31  1932 1936 1940 1944       1882       1945   Franklin D. Roosevelt
# 32               – 1948       1884       1972         Harry S. Truman
# 33            1952 1956       1890       1969    Dwight D. Eisenhower
# 34                 1960       1917       1963         John F. Kennedy
# 35               – 1964       1908       1973       Lyndon B. Johnson
# 36            1968 1972       1913       1994           Richard Nixon
# 37          No Election       1913       2006             Gerald Ford
# 38                 1976       1924      Alive            Jimmy Carter
# 39            1980 1984       1911       2004           Ronald Reagan
# 40                 1988       1924       2018       George H. W. Bush
# 41            1992 1996       1946      Alive            Bill Clinton
# 42            2000 2004       1946      Alive          George W. Bush
# 43            2008 2012       1961      Alive            Barack Obama
# 44                 2016       1946      Alive            Donald Trump
# 45                 2020       1942      Alive               Joe Biden
#
#                                        Vice President  \
# 0                                          John Adams
# 1                                    Thomas Jefferson
# 2                           Aaron Burr George Clinton
# 3                                      George Clinton
# 4                                  Daniel D. Tompkins
# 5                                     John C. Calhoun
# 6                                     John C. Calhoun
# 7                              Richard Mentor Johnson
# 8                                          John Tyler
# 9                        Vacant throughout presidency
# 10                                   George M. Dallas
# 11                                   Millard Fillmore
# 12                       Vacant throughout presidency
# 13                                    William R. King
# 14                               John C. Breckinridge
# 15                     Hannibal Hamlin Andrew Johnson
# 16                       Vacant throughout presidency
# 17                       Schuyler Colfax Henry Wilson
# 18                                 William A. Wheeler
# 19                                  Chester A. Arthur
# 20                       Vacant throughout presidency
# 21                                Thomas A. Hendricks
# 22                                     Levi P. Morton
# 23                                  Adlai Stevenson I
# 24                                      Garret Hobart
# 25  Vacant through March 4, 1905 Charles W. Fairbanks
# 26                                   James S. Sherman
# 27                                 Thomas R. Marshall
# 28                                    Calvin Coolidge
# 29      Vacant through March 4, 1925 Charles G. Dawes
# 30                                     Charles Curtis
# 31  John Nance Garner Henry A. Wallace Harry S. Tr...
# 32   Vacant through January 20, 1949 Alben W. Barkley
# 33                                      Richard Nixon
# 34                                  Lyndon B. Johnson
# 35    Vacant through January 20, 1965 Hubert Humphrey
# 36                                        Spiro Agnew
# 37  Vacant through December 19, 1974 Nelson Rockef...
# 38                                     Walter Mondale
# 39                                  George H. W. Bush
# 40                                         Dan Quayle
# 41                                            Al Gore
# 42                                        Dick Cheney
# 43                                          Joe Biden
# 44                                         Mike Pence
# 45                                      Kamala Harris
#
#                         Party                                  Term  \
# 0                Unaffiliated        April 30, 1789 – March 4, 1797
# 1                  Federalist         March 4, 1797 – March 4, 1801
# 2      Democratic- Republican         March 4, 1801 – March 4, 1809
# 3      Democratic- Republican         March 4, 1809 – March 4, 1817
# 4      Democratic- Republican         March 4, 1817 – March 4, 1825
# 5      Democratic- Republican         March 4, 1825 – March 4, 1829
# 6                  Democratic         March 4, 1829 – March 4, 1837
# 7                  Democratic         March 4, 1837 – March 4, 1841
# 8                        Whig         March 4, 1841 – April 4, 1841
# 9                        Whig                         April 4, 1841
# 10                 Democratic         March 4, 1845 – March 4, 1849
# 11                       Whig          March 4, 1849 – July 9, 1850
# 12                       Whig                          July 9, 1850
# 13                 Democratic         March 4, 1853 – March 4, 1857
# 14                 Democratic         March 4, 1857 – March 4, 1861
# 15  Republican National Union        March 4, 1861 – April 15, 1865
# 16             National Union                        April 15, 1865
# 17                 Republican         March 4, 1869 – March 4, 1877
# 18                 Republican         March 4, 1877 – March 4, 1881
# 19                 Republican    March 4, 1881 – September 19, 1881
# 20                 Republican                    September 19, 1881
# 21                 Democratic         March 4, 1885 – March 4, 1889
# 22                 Republican         March 4, 1889 – March 4, 1893
# 23                 Democratic         March 4, 1893 – March 4, 1897
# 24                 Republican    March 4, 1897 – September 14, 1901
# 25                 Republican                    September 14, 1901
# 26                 Republican         March 4, 1909 – March 4, 1913
# 27                 Democratic         March 4, 1913 – March 4, 1921
# 28                 Republican        March 4, 1921 – August 2, 1923
# 29                 Republican                        August 2, 1923
# 30                 Republican         March 4, 1929 – March 4, 1933
# 31                 Democratic        March 4, 1933 – April 12, 1945
# 32                 Democratic                        April 12, 1945
# 33                 Republican   January 20, 1953 – January 20, 1961
# 34                 Democratic  January 20, 1961 – November 22, 1963
# 35                 Democratic                     November 22, 1963
# 36                 Republican     January 20, 1969 – August 9, 1974
# 37                 Republican                        August 9, 1974
# 38                 Democratic   January 20, 1977 – January 20, 1981
# 39                 Republican   January 20, 1981 – January 20, 1989
# 40                 Republican   January 20, 1989 – January 20, 1993
# 41                 Democratic   January 20, 1993 – January 20, 2001
# 42                 Republican   January 20, 2001 – January 20, 2009
# 43                 Democratic   January 20, 2009 – January 20, 2017
# 44                 Republican   January 20, 2017 – January 20, 2021
# 45                 Democratic          January 20, 2021 – Incumbent
#
#     year entered office  year left office  Years in Office    Forename  \
# 0                  1789            1797.0                8      George
# 1                  1797            1801.0                4        John
# 2                  1801            1809.0                8      Thomas
# 3                  1809            1817.0                8       James
# 4                  1817            1825.0                8       James
# 5                  1825            1829.0                4        John
# 6                  1829            1837.0                8      Andrew
# 7                  1837            1841.0                4      Martin
# 8                  1841            1841.0                0     William
# 9                  1841               NaN                4        John
# 10                 1845            1849.0                4       James
# 11                 1849            1850.0                1     Zachary
# 12                 1850               NaN                3     Millard
# 13                 1853            1857.0                4    Franklin
# 14                 1857            1861.0                4       James
# 15                 1861            1865.0                4     Abraham
# 16                 1865               NaN                4      Andrew
# 17                 1869            1877.0                8     Ulysses
# 18                 1877            1881.0                4  Rutherford
# 19                 1881            1881.0                0       James
# 20                 1881               NaN                4     Chester
# 21                 1885            1889.0                4      Grover
# 22                 1889            1893.0                4    Benjamin
# 23                 1893            1897.0                4      Grover
# 24                 1897            1901.0                4     William
# 25                 1901               NaN                8    Theodore
# 26                 1909            1913.0                4     William
# 27                 1913            1921.0                8     Woodrow
# 28                 1921            1923.0                2      Warren
# 29                 1923               NaN                6      Calvin
# 30                 1929            1933.0                4     Herbert
# 31                 1933            1945.0               12    Franklin
# 32                 1945               NaN                8       Harry
# 33                 1953            1961.0                8      Dwight
# 34                 1961            1963.0                2        John
# 35                 1963               NaN                6      Lyndon
# 36                 1969            1974.0                5     Richard
# 37                 1974               NaN                3      Gerald
# 38                 1977            1981.0                4       Jimmy
# 39                 1981            1989.0                8      Ronald
# 40                 1989            1993.0                4      George
# 41                 1993            2001.0                8        Bill
# 42                 2001            2009.0                8      George
# 43                 2009            2017.0                8      Barack
# 44                 2017            2021.0                4      Donald
# 45                 2021            2024.0                3         Joe
#
#        Surname      VP                                  VP more than once
# 0   Washington                                                 John Adams
# 1        Adams   Short
# 2    Jefferson                                  Aaron Burr George Clinton
# 3      Madison                                             George Clinton
# 4       Monroe                                         Daniel D. Tompkins
# 5        Adams   Short
# 6      Jackson                                            John C. Calhoun
# 7        Buren   Short
# 8     Harrison   Short
# 9        Tyler   Short
# 10        Polk   Short
# 11      Taylor   Short
# 12    Fillmore   Short
# 13      Pierce   Short
# 14    Buchanan   Short
# 15     Lincoln   Short
# 16     Johnson   Short
# 17       Grant                               Schuyler Colfax Henry Wilson
# 18       Hayes   Short
# 19    Garfield   Short
# 20      Arthur   Short
# 21   Cleveland   Short
# 22    Harrison   Short
# 23   Cleveland   Short
# 24    McKinley   Short
# 25   Roosevelt  Vacant
# 26        Taft   Short
# 27      Wilson                                         Thomas R. Marshall
# 28     Harding   Short
# 29    Coolidge  Vacant
# 30      Hoover   Short
# 31   Roosevelt          John Nance Garner Henry A. Wallace Harry S. Tr...
# 32      Truman  Vacant
# 33  Eisenhower                                              Richard Nixon
# 34     Kennedy   Short
# 35     Johnson  Vacant
# 36       Nixon                                                Spiro Agnew
# 37        Ford   Short
# 38      Carter   Short
# 39      Reagan                                          George H. W. Bush
# 40        Bush   Short
# 41     Clinton                                                    Al Gore
# 42        Bush                                                Dick Cheney
# 43       Obama                                                  Joe Biden
# 44       Trump   Short
# 45       Biden   Short

# %%
for i in range(len(df)):
    if (df["Death Year"][i] == 'Alive'):
        df["Death Year"][i] = 0
    else:
        if pd.isna(df["year left office"][i]):
            df["year left office"][i] = 0

        oldest = int(df["Death Year"][i]) - int(df["year left office"][i])
        if oldest > oldest_age:
            oldest_age = oldest
            presname = df['Name'][i]
            tenure_began = df['Election'][i]
            tenure_end = df['year left office'][i]
# Out:
# /var/folders/wt/b9wfm1hx0s9gb4gpzpv0xyq40000gn/T/ipykernel_23320/622733110.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["year left office"][i] = 0
# /var/folders/wt/b9wfm1hx0s9gb4gpzpv0xyq40000gn/T/ipykernel_23320/622733110.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Death Year"][i] = 0

# %%
print(f"Name: {presname}")
print(f"Age: {oldest_age}")
print(f"Year elected: {tenure_began}")
print(f"Year tenure ended: {int(tenure_end)}")
# Out:
# Name: Gerald Ford
# Age: 2006
# Year elected: No Election
# Year tenure ended: 0

# %% [markdown]
# ### Question 12: Draw a graph that shows the number of presidents and their respective political parties which they came from, and which party have many elected presidents?

# %%
df

# %%
# no of pres
# political parties
# party with the most presidents
import matplotlib.pyplot as plt


# df.plot()

df.plot(kind = 'scatter', x = 'Name', y = 'Party')

# df["Years in office"].plot(kind = 'hist')

plt.show()

# %%
# `# Plotting - from web
# In [3]: np.random.seed(123456)

# In [4]: ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

# In [5]: ts = ts.cumsum()

# In [6]: ts.plot();`

# https://pandas.pydata.org/docs/user_guide/visualization.html

# %% [markdown]
# code below works. requires further cleaning of vacant columns.
# we will strip vacant through
# then we will add the cleaning for the commas again
# then we can finally perform the operation

# %%
df
# Out:
#                Election Birth Year Death Year                    Name  \
# 0        1788–1789 1792       1732       1799       George Washington
# 1                  1796       1735       1826              John Adams
# 2             1800 1804       1743       1826        Thomas Jefferson
# 3             1808 1812       1751       1836           James Madison
# 4             1816 1820       1758       1831            James Monroe
# 5                  1824       1767       1848       John Quincy Adams
# 6             1828 1832       1767       1845          Andrew Jackson
# 7                  1836       1782       1862        Martin Van Buren
# 8                  1840       1773       1841  William Henry Harrison
# 9           No Election       1790       1862              John Tyler
# 10                 1844       1795       1849           James K. Polk
# 11                 1848       1784       1850          Zachary Taylor
# 12          No Election       1800       1874        Millard Fillmore
# 13                 1852       1804       1869         Franklin Pierce
# 14                 1856       1791       1868          James Buchanan
# 15            1860 1864       1809       1865         Abraham Lincoln
# 16          No Election       1808       1875          Andrew Johnson
# 17            1868 1872       1822       1885        Ulysses S. Grant
# 18                 1876       1822       1893     Rutherford B. Hayes
# 19                 1880       1831       1881       James A. Garfield
# 20          No Election       1829       1886       Chester A. Arthur
# 21                 1884       1837       1908        Grover Cleveland
# 22                 1888       1833       1901       Benjamin Harrison
# 23                 1892       1837       1908        Grover Cleveland
# 24            1896 1900       1843       1901        William McKinley
# 25               – 1904       1858       1919      Theodore Roosevelt
# 26                 1908       1857       1930     William Howard Taft
# 27            1912 1916       1856       1924          Woodrow Wilson
# 28                 1920       1865       1923       Warren G. Harding
# 29               – 1924       1872       1933         Calvin Coolidge
# 30                 1928       1874       1964          Herbert Hoover
# 31  1932 1936 1940 1944       1882       1945   Franklin D. Roosevelt
# 32               – 1948       1884       1972         Harry S. Truman
# 33            1952 1956       1890       1969    Dwight D. Eisenhower
# 34                 1960       1917       1963         John F. Kennedy
# 35               – 1964       1908       1973       Lyndon B. Johnson
# 36            1968 1972       1913       1994           Richard Nixon
# 37          No Election       1913       2006             Gerald Ford
# 38                 1976       1924          0            Jimmy Carter
# 39            1980 1984       1911       2004           Ronald Reagan
# 40                 1988       1924       2018       George H. W. Bush
# 41            1992 1996       1946          0            Bill Clinton
# 42            2000 2004       1946          0          George W. Bush
# 43            2008 2012       1961          0            Barack Obama
# 44                 2016       1946          0            Donald Trump
# 45                 2020       1942          0               Joe Biden
#
#                                        Vice President  \
# 0                                          John Adams
# 1                                    Thomas Jefferson
# 2                           Aaron Burr George Clinton
# 3                                      George Clinton
# 4                                  Daniel D. Tompkins
# 5                                     John C. Calhoun
# 6                                     John C. Calhoun
# 7                              Richard Mentor Johnson
# 8                                          John Tyler
# 9                        Vacant throughout presidency
# 10                                   George M. Dallas
# 11                                   Millard Fillmore
# 12                       Vacant throughout presidency
# 13                                    William R. King
# 14                               John C. Breckinridge
# 15                     Hannibal Hamlin Andrew Johnson
# 16                       Vacant throughout presidency
# 17                       Schuyler Colfax Henry Wilson
# 18                                 William A. Wheeler
# 19                                  Chester A. Arthur
# 20                       Vacant throughout presidency
# 21                                Thomas A. Hendricks
# 22                                     Levi P. Morton
# 23                                  Adlai Stevenson I
# 24                                      Garret Hobart
# 25  Vacant through March 4, 1905 Charles W. Fairbanks
# 26                                   James S. Sherman
# 27                                 Thomas R. Marshall
# 28                                    Calvin Coolidge
# 29      Vacant through March 4, 1925 Charles G. Dawes
# 30                                     Charles Curtis
# 31  John Nance Garner Henry A. Wallace Harry S. Tr...
# 32   Vacant through January 20, 1949 Alben W. Barkley
# 33                                      Richard Nixon
# 34                                  Lyndon B. Johnson
# 35    Vacant through January 20, 1965 Hubert Humphrey
# 36                                        Spiro Agnew
# 37  Vacant through December 19, 1974 Nelson Rockef...
# 38                                     Walter Mondale
# 39                                  George H. W. Bush
# 40                                         Dan Quayle
# 41                                            Al Gore
# 42                                        Dick Cheney
# 43                                          Joe Biden
# 44                                         Mike Pence
# 45                                      Kamala Harris
#
#                         Party                                  Term  \
# 0                Unaffiliated        April 30, 1789 – March 4, 1797
# 1                  Federalist         March 4, 1797 – March 4, 1801
# 2      Democratic- Republican         March 4, 1801 – March 4, 1809
# 3      Democratic- Republican         March 4, 1809 – March 4, 1817
# 4      Democratic- Republican         March 4, 1817 – March 4, 1825
# 5      Democratic- Republican         March 4, 1825 – March 4, 1829
# 6                  Democratic         March 4, 1829 – March 4, 1837
# 7                  Democratic         March 4, 1837 – March 4, 1841
# 8                        Whig         March 4, 1841 – April 4, 1841
# 9                        Whig                         April 4, 1841
# 10                 Democratic         March 4, 1845 – March 4, 1849
# 11                       Whig          March 4, 1849 – July 9, 1850
# 12                       Whig                          July 9, 1850
# 13                 Democratic         March 4, 1853 – March 4, 1857
# 14                 Democratic         March 4, 1857 – March 4, 1861
# 15  Republican National Union        March 4, 1861 – April 15, 1865
# 16             National Union                        April 15, 1865
# 17                 Republican         March 4, 1869 – March 4, 1877
# 18                 Republican         March 4, 1877 – March 4, 1881
# 19                 Republican    March 4, 1881 – September 19, 1881
# 20                 Republican                    September 19, 1881
# 21                 Democratic         March 4, 1885 – March 4, 1889
# 22                 Republican         March 4, 1889 – March 4, 1893
# 23                 Democratic         March 4, 1893 – March 4, 1897
# 24                 Republican    March 4, 1897 – September 14, 1901
# 25                 Republican                    September 14, 1901
# 26                 Republican         March 4, 1909 – March 4, 1913
# 27                 Democratic         March 4, 1913 – March 4, 1921
# 28                 Republican        March 4, 1921 – August 2, 1923
# 29                 Republican                        August 2, 1923
# 30                 Republican         March 4, 1929 – March 4, 1933
# 31                 Democratic        March 4, 1933 – April 12, 1945
# 32                 Democratic                        April 12, 1945
# 33                 Republican   January 20, 1953 – January 20, 1961
# 34                 Democratic  January 20, 1961 – November 22, 1963
# 35                 Democratic                     November 22, 1963
# 36                 Republican     January 20, 1969 – August 9, 1974
# 37                 Republican                        August 9, 1974
# 38                 Democratic   January 20, 1977 – January 20, 1981
# 39                 Republican   January 20, 1981 – January 20, 1989
# 40                 Republican   January 20, 1989 – January 20, 1993
# 41                 Democratic   January 20, 1993 – January 20, 2001
# 42                 Republican   January 20, 2001 – January 20, 2009
# 43                 Democratic   January 20, 2009 – January 20, 2017
# 44                 Republican   January 20, 2017 – January 20, 2021
# 45                 Democratic          January 20, 2021 – Incumbent
#
#     year entered office  year left office  Years in Office    Forename  \
# 0                  1789            1797.0                8      George
# 1                  1797            1801.0                4        John
# 2                  1801            1809.0                8      Thomas
# 3                  1809            1817.0                8       James
# 4                  1817            1825.0                8       James
# 5                  1825            1829.0                4        John
# 6                  1829            1837.0                8      Andrew
# 7                  1837            1841.0                4      Martin
# 8                  1841            1841.0                0     William
# 9                  1841               NaN                4        John
# 10                 1845            1849.0                4       James
# 11                 1849            1850.0                1     Zachary
# 12                 1850               NaN                3     Millard
# 13                 1853            1857.0                4    Franklin
# 14                 1857            1861.0                4       James
# 15                 1861            1865.0                4     Abraham
# 16                 1865               NaN                4      Andrew
# 17                 1869            1877.0                8     Ulysses
# 18                 1877            1881.0                4  Rutherford
# 19                 1881            1881.0                0       James
# 20                 1881               NaN                4     Chester
# 21                 1885            1889.0                4      Grover
# 22                 1889            1893.0                4    Benjamin
# 23                 1893            1897.0                4      Grover
# 24                 1897            1901.0                4     William
# 25                 1901               NaN                8    Theodore
# 26                 1909            1913.0                4     William
# 27                 1913            1921.0                8     Woodrow
# 28                 1921            1923.0                2      Warren
# 29                 1923               NaN                6      Calvin
# 30                 1929            1933.0                4     Herbert
# 31                 1933            1945.0               12    Franklin
# 32                 1945               NaN                8       Harry
# 33                 1953            1961.0                8      Dwight
# 34                 1961            1963.0                2        John
# 35                 1963               NaN                6      Lyndon
# 36                 1969            1974.0                5     Richard
# 37                 1974               NaN                3      Gerald
# 38                 1977            1981.0                4       Jimmy
# 39                 1981            1989.0                8      Ronald
# 40                 1989            1993.0                4      George
# 41                 1993            2001.0                8        Bill
# 42                 2001            2009.0                8      George
# 43                 2009            2017.0                8      Barack
# 44                 2017            2021.0                4      Donald
# 45                 2021            2024.0                3         Joe
#
#        Surname      VP                                  VP more than once
# 0   Washington                                                 John Adams
# 1        Adams   Short
# 2    Jefferson                                  Aaron Burr George Clinton
# 3      Madison                                             George Clinton
# 4       Monroe                                         Daniel D. Tompkins
# 5        Adams   Short
# 6      Jackson                                            John C. Calhoun
# 7        Buren   Short
# 8     Harrison   Short
# 9        Tyler   Short
# 10        Polk   Short
# 11      Taylor   Short
# 12    Fillmore   Short
# 13      Pierce   Short
# 14    Buchanan   Short
# 15     Lincoln   Short
# 16     Johnson   Short
# 17       Grant                               Schuyler Colfax Henry Wilson
# 18       Hayes   Short
# 19    Garfield   Short
# 20      Arthur   Short
# 21   Cleveland   Short
# 22    Harrison   Short
# 23   Cleveland   Short
# 24    McKinley   Short
# 25   Roosevelt  Vacant
# 26        Taft   Short
# 27      Wilson                                         Thomas R. Marshall
# 28     Harding   Short
# 29    Coolidge  Vacant
# 30      Hoover   Short
# 31   Roosevelt          John Nance Garner Henry A. Wallace Harry S. Tr...
# 32      Truman  Vacant
# 33  Eisenhower                                              Richard Nixon
# 34     Kennedy   Short
# 35     Johnson  Vacant
# 36       Nixon                                                Spiro Agnew
# 37        Ford   Short
# 38      Carter   Short
# 39      Reagan                                          George H. W. Bush
# 40        Bush   Short
# 41     Clinton                                                    Al Gore
# 42        Bush                                                Dick Cheney
# 43       Obama                                                  Joe Biden
# 44       Trump   Short
# 45       Biden   Short
