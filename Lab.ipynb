# %% [markdown]
# # Nana Kwaku Amoako
# ## Lab: Life Expentacy
# ### Jun 10, 2024

# %% [markdown]
# ### Import modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Life Expectancy Data.csv")

# %%
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %% [markdown]
# ## Data Analysis and Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.value_counts()
# Out:
# Country      Year  Status      Life expectancy   Adult Mortality  infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   Polio  Total expenditure  Diphtheria    HIV/AIDS  GDP          Population   thinness  1-19 years   thinness 5-9 years  Income composition of resources  Schooling
# Afghanistan  2000  Developing  54.8              321.0            88             0.01     10.424960               62.0         6532      12.2   122                 24.0   8.20               24.0         0.1        114.560000   293756.0    2.3                    2.5                  0.338                            5.5          1
# Nicaragua    2005  Developing  71.2              194.0            3              3.70     218.571618              86.0         0         46.4   4                   87.0   6.11               86.0         0.3        1175.116225  5379328.0   2.0                    1.9                  0.592                            11.0         1
# ...

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# ### CHeck NAs

# %%
no_nas = True
for col in df.columns:
    if df[col].isnull().any():
        print(f"There are nulls in: {col}")
        no_nas = False

if no_nas:
    print("Yup, all good no NAs in any column")
# Out:
# There are nulls in: Life expectancy
# There are nulls in: Adult Mortality
# There are nulls in: Alcohol
# There are nulls in: Hepatitis B
# There are nulls in:  BMI
# There are nulls in: Polio
# There are nulls in: Total expenditure
# There are nulls in: Diphtheria
# There are nulls in: GDP
# There are nulls in: Population
# There are nulls in:  thinness  1-19 years
# There are nulls in:  thinness 5-9 years
# There are nulls in: Income composition of resources
# There are nulls in: Schooling

# %%
for col in df.columns:
    print(f"{col}")
# Out:
# Country
# Year
# Status
# Life expectancy
# Adult Mortality
# infant deaths
# Alcohol
# percentage expenditure
# Hepatitis B
# Measles
#  BMI
# under-five deaths
# Polio
# Total expenditure
# Diphtheria
#  HIV/AIDS
# GDP
# Population
#  thinness  1-19 years
#  thinness 5-9 years
# Income composition of resources
# Schooling

# %%
missing_columns = [col for col in df.columns if df[col].isnull().sum() > len(df) / 2]
missing_columns
# Out:
# []

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
# fill NAs objects with mode
# fill NAs int, float with mean
for col in df.columns:
    if df[col].dtype == 'object':
        df[col].fillna(df[col].mode()[0], inplace=True)
    else:
        df[col].fillna(df[col].median(), inplace=True)

# %%
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df.to_csv("output life.csv")

# %% [markdown]
# ### 1. Should a country having a lower life expectancy value (<65) increase its healthcare expenditure in order to improve its average lifespan?

# %% [markdown]
# Feature Selection

# %%
# use corr matrix to identify important features
corr_matrix = df.corr()
life_expectancy_corr = corr_matrix['Life expectancy '].sort_values(ascending=False)
life_expectancy_corr
# Out:
# /var/folders/wt/b9wfm1hx0s9gb4gpzpv0xyq40000gn/T/ipykernel_15754/2053377801.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
# Life expectancy                    1.000000
# Schooling                          0.713054
# Income composition of resources    0.688662
#  BMI                               0.556901
# Diphtheria                         0.472211
# Polio                              0.458399
# GDP                                0.430461
# Alcohol                            0.388918
# percentage expenditure             0.381418
# Total expenditure                  0.208844
# Year                               0.170819
# Hepatitis B                        0.170219
# Population                        -0.029014
# Measles                           -0.157767
# ...

# %% [markdown]
# Create new column using GDP and percentage expenditure to find amounts spent on healthcare

# %%
df["Healthcare Expenditure"] = df['percentage expenditure'] * df['GDP']

# %%
df["Healthcare Expenditure"]
# Out:
# 0       41645.776585
# 1       45047.642192
# 2       46255.888735
# 3       52380.218698
# 4         450.930635
#             ...
# 2933        0.000000
# 2934        0.000000
# 2935        0.000000
# 2936        0.000000
# 2937        0.000000
# Name: Healthcare Expenditure, Length: 2938, dtype: float64

# %%
low_life_expect = df[df['Life expectancy '] < 65]

# %%
low_life_expect
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# 5     Afghanistan  2010  Developing              58.8            279.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
corr = low_life_expect['Healthcare Expenditure'].corr(low_life_expect['Life expectancy '])

# %%
corr
# Out:
# -0.0004551454681706632

# %% [markdown]
# ### Answer:
# The correlation implies that an increase in healthcare expenditure does not increase life expectnacy in countries with a lower life expectancy value (<65). Hence a country with a lower life expectancy value (<65) shouldn't increase it's expenditure

# %% [markdown]
# ### 2.	How does Infant and Adult mortality rates affect life expectancy?

# %% [markdown]
# Correlation Analysis

# %% [markdown]
# divide by 1000 and concat adult mort and infant death cols

# %%
#divide by 1000 and concat adult mort and infant death cols
df['Infant & Adult Mortality'] = df['infant deaths']/1000 + df['Adult Mortality']/1000
df['Infant & Adult Mortality']
# Out:
# 0       0.325
# 1       0.335
# 2       0.334
# 3       0.341
# 4       0.346
#         ...
# 2933    0.750
# 2934    0.741
# 2935    0.098
# 2936    0.711
# 2937    0.689
# Name: Infant & Adult Mortality, Length: 2938, dtype: float64

# %%
corr_2 = df['Infant & Adult Mortality'].corr(df['Life expectancy '])

# %%
corr_2
# Out:
# -0.6165167235128922

# %% [markdown]
# ### Answer:
#
# Infant and Adult mortality rates reduce life expectancy

# %% [markdown]
# ### 3. Does Life Expectancy have positive or negative correlation with eating habits, lifestyle, exercise, smoking, drinking alcohol etc.

# %%
corr_4 = df[' BMI '].corr(df['Life expectancy '])
corr_4
# Out:
# 0.556901168485039

# %% [markdown]
# ### Answer:
#
# Life Expectancy have positive correlation with eating habits, lifestyle, exercise, smoking, drinking alcohol.

# %% [markdown]
# ### 4.	What is the impact of schooling on the lifespan of humans?

# %%
corr_5 = df['Schooling'].corr(df['Life expectancy '])
corr_5
# Out:
# 0.7130535310931975

# %% [markdown]
# ### Answer:
#
# Schooling has a strong positive correlation on the life expectancy which implies an increase in life expentancy

# %% [markdown]
# ### 5.	Does Life Expectancy have a positive or negative relationship with drinking alcohol?

# %%
corr_6 = df['Alcohol'].corr(df['Life expectancy '])
corr_6
# Out:
# 0.3889175377541888

# %% [markdown]
# ### Answer:

# %%
print(f"Alcohol consumption have a life expectancy have a positive correlation of {corr_6}")
# Out:
# Alcohol consumption have a life expectancy have a positive correlation of 0.3889175377541888

# %% [markdown]
# ### 6.	Do densely populated countries tend to have lower life expectancy?

# %% [markdown]
# 1. Define densely populated countries. Threshold = top 25%

# %%
df['Densely Populated'] = df['Population'] > df['Population'].quantile(0.75)
df['Densely Populated']
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 2933     True
# 2934     True
# 2935    False
# 2936     True
# 2937     True
# Name: Densely Populated, Length: 2938, dtype: bool

# %% [markdown]
# 2. Assign to new df

# %%
dense_pop = df[df['Densely Populated']]

# %%
dense_pop
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 8     Afghanistan  2007  Developing              57.5            295.0
# 11    Afghanistan  2004  Developing              57.0            293.0
# 13    Afghanistan  2002  Developing              56.2              3.0
# ...           ...   ...         ...               ...              ...
# 2931     Zimbabwe  2006  Developing              45.4              7.0
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %% [markdown]
# 3. Calculate correlation of densely populated countries

# %%
corr_9 = df['Population'].corr(df['Life expectancy '])
corr_9
# Out:
# -0.02901387686318796

# %% [markdown]
# ### Answer:
#
# Population density and life expentency have a weak negative correlation which implies that an increased population reduces life expentancy at a minimal level.

# %% [markdown]
# ### 7.	What is the impact of Immunization coverage on life Expectancy?

# %% [markdown]
# 1. Concatenate columns of diseases to be immunized

# %%
df['Total Immunization Coverage'] = df[['Polio', 'Hepatitis B', 'Diphtheria ', 'Measles ']].sum(axis=1)
df['Total Immunization Coverage']
# Out:
# 0       1290.0
# 1        674.0
# 2        620.0
# 3       2988.0
# 4       3217.0
#          ...
# 2933     231.0
# 2934    1080.0
# 2935     521.0
# 2936     756.0
# 2937    1718.0
# Name: Total Immunization Coverage, Length: 2938, dtype: float64

# %% [markdown]
# 2. Find correlation

# %%
corr10 = df['Total Immunization Coverage'].corr(df['Life expectancy '])
corr10
# Out:
# -0.155626973503572

# %% [markdown]
# ### Answer:
#
# Given that the correlation is negative, there is a weak inverse relationship between immunization coverage and life expectancy

# %% [markdown]
# ### 8.	What are the predicting variables actually affecting life expectancy?

# %%
corr_matrix_4 = df.corr()
# Out:
# /var/folders/wt/b9wfm1hx0s9gb4gpzpv0xyq40000gn/T/ipykernel_15754/602984937.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix_4 = df.corr()

# %%
corr_matrix_4['Life expectancy '].sort_values(ascending=False)
# Out:
# Life expectancy                    1.000000
# Schooling                          0.713054
# Income composition of resources    0.688662
#  BMI                               0.556901
# Diphtheria                         0.472211
# Polio                              0.458399
# GDP                                0.430461
# Alcohol                            0.388918
# percentage expenditure             0.381418
# Healthcare Expenditure             0.264445
# Total expenditure                  0.208844
# Year                               0.170819
# Hepatitis B                        0.170219
# Population                        -0.029014
# Densely Populated                 -0.054878
# Total Immunization Coverage       -0.155627
# Measles                           -0.157767
# infant deaths                     -0.196769
# under-five deaths                 -0.222738
#  thinness 5-9 years               -0.462473
#  thinness  1-19 years             -0.468002
# ...

# %%
corr_dict = corr_matrix_4['Life expectancy '].to_dict()

pos = {}
neg = {}

for key, value in corr_dict.items():
    if value > 0:
        pos[key] = value
    else:
        neg[key] = value

print("Factors positively affecting Life Expectancy:")
for factor, value in pos.items():
    print(f"{factor}")


print("\nFactors negatively affecting Life Expectancy:")
for factor, value in neg.items():
    print(f"{factor}")
# Out:
# Factors positively affecting Life Expectancy:
# Year
# Life expectancy
# Alcohol
# percentage expenditure
# Hepatitis B
#  BMI
# Polio
# Total expenditure
# Diphtheria
# GDP
# Income composition of resources
# Schooling
# Healthcare Expenditure
#
# Factors negatively affecting Life Expectancy:
# Adult Mortality
# infant deaths
# Measles
# under-five deaths
#  HIV/AIDS
# Population
#  thinness  1-19 years
#  thinness 5-9 years
# Infant & Adult Mortality
# Densely Populated
# Total Immunization Coverage

# %% [markdown]
# ### Answer:

# %% [markdown]
# ### 9.	Train and test at least 3 regression models and pick the best performing model to predict life expectancy

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df2 = df.drop(columns=['Country', 'Year', 'Status'])

# %%
df2.columns = df2.columns.str.strip()

# %%
y = df2['Life expectancy']
x = df2.drop('Life expectancy', axis = 1)

# %%
scale = StandardScaler()
scaled = scale.fit_transform(x)

# %%
x = pd.DataFrame(scaled, columns = x.columns)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(x, y,test_size = 0.2, random_state = 42)

# %%
Xtrain.shape
# Out:
# (2350, 22)

# %%
Xtrain.head()
# Out:
#       Adult Mortality  infant deaths   Alcohol  percentage expenditure  \
# 456         -0.312140      -0.257017  0.186961               -0.197621
# 462         -0.102572      -0.257017 -0.187917               -0.295590
# 2172        -0.175115      -0.257017  1.500308               -0.371433
# 2667        -1.222952      -0.231573 -0.830565               -0.072252
# 381         -0.562009      -0.257017 -1.126387                0.102362
#
#       Hepatitis B   Measles       BMI  under-five deaths     Polio  \
# 456      0.564426 -0.211036 -0.646257          -0.262038  0.658396
# 462      0.390460 -0.211036 -0.816837          -0.262038  0.358779
# 2172     0.694900 -0.211036  0.306985          -0.262038  0.701199
# 2667     0.651408 -0.209640  1.049510          -0.243337  0.658396
# 381      0.694900 -0.211036 -0.520830          -0.262038  0.701199
#
#       Total expenditure  ...       GDP  Population  thinness  1-19 years  \
# ...

# %%
y_test
# Out:
# 348     46.4
# 1021    58.3
# 2310    48.0
# 2783    57.5
# 1388    64.9
#         ...
# 1129    62.1
# 8       57.5
# 1656    62.0
# 526     45.6
# 1779    49.0
# Name: Life expectancy , Length: 171, dtype: float64

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()
lin_reg.fit(Xtrain, Ytrain)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(Xtest)

# %%
intercept = lin_reg.intercept_
coefficients = lin_reg.coef_

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ### Polynomial Regression

# %%
# Create polynomial features
poly = PolynomialFeatures(degree=3)
X_poly_train = poly.fit_transform(Xtrain)
X_poly_test = poly.fit_transform(Xtest)

# %%
# Train the model
model = LinearRegression()
model.fit(X_poly_train, Ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# Test model

# %%
# Test the model
y_pred = model.predict(X_poly_test)

# %%
print(f"""
Mean Absolute Error: {mean_absolute_error(y_pred, Ytest)},
Mean Squared Error: {mean_squared_error(y_pred, Ytest)},
Root Mean Squared Error: {np.sqrt(mean_squared_error(y_pred, Ytest))},
R2 Score: {r2_score(y_pred, Ytest)}
""")
# Out:
# Mean Absolute Error: 91.9561568461308,
# Mean Squared Error: 358700.7089297584,
# Root Mean Squared Error: 598.9162787316425,
# R2 Score: -0.0001190189771613781

# %% [markdown]
# ### Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
dtree = DecisionTreeRegressor(max_depth=12)

# %%
dtree.fit(Xtrain, Ytrain)
# Out:
# DecisionTreeRegressor(max_depth=12)

# %%
y_pred = dtree.predict(Xtest)

# %%
print(f"""
Mean Absolute Error: {mean_absolute_error(y_pred, Ytest)},
Mean Squared Error: {mean_squared_error(y_pred, Ytest)},
Root Mean Squared Error: {np.sqrt(mean_squared_error(y_pred, Ytest))},
R2 Score: {r2_score(y_pred, Ytest)}
""")
# Out:
# Mean Absolute Error: 1.578019233428623,
# Mean Squared Error: 6.266263897645767,
# Root Mean Squared Error: 2.5032506661630527,
# R2 Score: 0.9294374537419502

# %% [markdown]
# ### Answer:
# From the above models, Decision Tree Regressor is the besst model to predict life expentancy
